# %%
import pandas as pd
from pathlib import Path
pd.__version__
# Out:
# '3.0.3'

# %%
yearmonths = []
solds = []
lists = []
for year in [24, 25, 26]:
    if year == 24:
        months = range(1, 13)
    elif year == 25:
        months = range(1, 13)
    else:               # 2026
        months = range(1, 5)

    for month in months:
        yearmonths.append(f"20{year:02d}{month:02d}")

# %%
for yearmonth in yearmonths:
    listfilename = Path("CRMLSListing" + yearmonth + ".csv")
    lists.append(pd.read_csv(listfilename))

    soldfilename = Path("CRMLSSold" + yearmonth + ".csv")
    if soldfilename.exists():
        solds.append(pd.read_csv(soldfilename))
    else:
        soldfilename = Path("CRMLSSold" + yearmonth + "_filled.csv")
        solds.append(pd.read_csv(soldfilename).iloc[:, :-2]) #drop last two clumns
# Out:
# C:\Users\ericy\AppData\Local\Temp\ipykernel_26960\1750076455.py:7: DtypeWarning: Columns (0: WaterfrontYN, 1: ElementarySchool, 2: BuilderName, 3: CoBuyerAgentFirstName, 4: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   solds.append(pd.read_csv(soldfilename))
# C:\Users\ericy\AppData\Local\Temp\ipykernel_26960\1750076455.py:7: DtypeWarning: Columns (0: WaterfrontYN) have mixed types. Specify dtype option on import or set low_memory=False.
#   solds.append(pd.read_csv(soldfilename))
# C:\Users\ericy\AppData\Local\Temp\ipykernel_26960\1750076455.py:7: DtypeWarning: Columns (0: WaterfrontYN, 1: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   solds.append(pd.read_csv(soldfilename))
# C:\Users\ericy\AppData\Local\Temp\ipykernel_26960\1750076455.py:3: DtypeWarning: Columns (0: ElementarySchool, 1: BusinessType, 2: MiddleOrJuniorSchool, 3: HighSchool) have mixed types. Specify dtype option on import or set low_memory=False.
#   lists.append(pd.read_csv(listfilename))

# %%
sold = pd.concat(solds)
print('sold before concatenation')
print(sold.shape)
list = pd.concat(lists)
print('list before concatenation')
print(list.shape)
soldfiltered = sold[sold['PropertyType'] == 'Residential']
listfiltered = list[list['PropertyType'] == 'Residential']
print('sold after concatenation')
print(soldfiltered.shape)
print('list after concatenation')
print(listfiltered.shape)
# Out:
# sold before concatenation
# (615725, 82)
# list before concatenation
# (893594, 84)
# sold after concatenation
# (414063, 82)
# list after concatenation
# (567549, 84)

# %%
sold.to_csv('sold.csv', index=False)
list.to_csv('list.csv', index=False)
soldfiltered.to_csv('soldfiltered.csv', index=False)
listfiltered.to_csv('listfiltered.csv', index=False)

# %%
#for investigation
pairs = [
    ("Latitude", "Latitude.1"),
    ("Longitude", "Longitude.1"),
    ("LivingArea", "LivingArea.1"),
    ("CloseDate", "CloseDate.1"),
    ("ListPrice", "ListPrice.1"),
]

for yearmonth in yearmonths:
    listfilename = Path("CRMLSListing" + yearmonth + ".csv")
    df = pd.read_csv(listfilename)
    dup = [c for c in df.columns if c.endswith(".1")]
    if dup:
        print(listfilename)
        print(dup)
        for a, b in pairs:
            if a in df.columns and b in df.columns:
                print(a, df[a].equals(df[b]))
# Out:
# CRMLSListing202401.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202402.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202403.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202404.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202405.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202406.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202407.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202408.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202409.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202410.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202411.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202412.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202501.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202502.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202503.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202504.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202505.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202506.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202507.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202508.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202509.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202510.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202511.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202512.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202601.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# C:\Users\ericy\AppData\Local\Temp\ipykernel_26960\3890702740.py:13: DtypeWarning: Columns (0: ElementarySchool, 1: BusinessType, 2: MiddleOrJuniorSchool, 3: HighSchool) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(listfilename)
# CRMLSListing202602.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202603.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
# CRMLSListing202604.csv
# ['PropertyType.1', 'ListAgentFirstName.1', 'DaysOnMarket.1', 'LivingArea.1', 'Longitude.1', 'Latitude.1', 'ListPrice.1', 'ListAgentLastName.1', 'CloseDate.1', 'BuyerOfficeName.1', 'UnparsedAddress.1']
# Latitude True
# Longitude True
# LivingArea True
# CloseDate True
# ListPrice True
